# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Analysis:
#     1. As expected, locations nearest the equator report higher maximum temperatures as a collective grouping. As locations get further from the equator in either hemisphere, their corresponding temperatures decrease to establish a parabolic relationship between latitude and maximum temperature. This relationship is centered along the equator. 
#     2. There appears to be a greater reporting of the extremities of cloudiness across the latitudes (i.e. more locations reported cloudiness between 0-10% and 80-100% than those reporting 10-80%). Cloudiness appears to be more evenly distributed in the southern hemisphere than the northern hemisphere. 
#     3. The range of reported wind speeds increases as latitudes move away from the equator. There also seems to be significantly greater windspeeds reported around 60 degrees latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
from urllib.error import HTTPError
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

#list(lat_lngs)

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:    
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %%
cities
# Out:
# ['attawapiskat',
#  'punta arenas',
#  'luderitz',
#  'cozumel',
#  'illoqqortoormiut',
#  'pisco',
#  'hermanus',
#  'thompson',
#  'port alfred',
#  'mar del plata',
#  'kodiak',
#  'albany',
#  'ushuaia',
#  'upernavik',
#  'lensk',
#  'qaanaaq',
#  'tsihombe',
#  'rikitea',
#  'port elizabeth',
#  'kanashevo',
#  'broome',
#  'hovd',
#  'cabo san lucas',
#  'nuuk',
#  'ponta do sol',
#  'mount gambier',
#  'tasbuget',
#  'vostok',
#  'donegal',
#  'adrar',
#  'east london',
#  'sao jose da coroa grande',
#  'bluff',
#  'mataura',
#  'saldanha',
#  'atuona',
#  'gat',
#  'huangmei',
#  'namatanai',
#  'fayaoue',
#  'gamba',
#  'kapaa',
#  'phonhong',
#  'nueve de julio',
#  'hami',
#  'castro',
#  'samusu',
#  'qaqortoq',
#  'lebu',
#  'grand river south east',
#  'mount isa',
#  'sardarshahr',
#  'dingli',
#  'vaini',
#  'tiznit',
#  'pathein',
#  'pevek',
#  'san quintin',
#  'saskylakh',
#  'dunedin',
#  'puerto ayora',
#  'padang',
#  'keokuk',
#  'asau',
#  'la asuncion',
#  'new norfolk',
#  'ekhabi',
#  'acara',
#  'oxapampa',
#  'magistralnyy',
#  'gizo',
#  'barrow',
#  'khatanga',
#  'belushya guba',
#  'tugulym',
#  'cape town',
#  'svetlyy',
#  'gopalpur',
#  'hurricane',
#  'meyungs',
#  'guayaramerin',
#  'ancud',
#  'balogo',
#  'nikolskoye',
#  'victoria',
#  'hay river',
#  'flin flon',
#  'kavieng',
#  'kongolo',
#  'bursa',
#  'butaritari',
#  'kruisfontein',
#  'doha',
#  'qeshm',
#  'hobart',
#  'bredasdorp',
#  'tarbagatay',
#  'saleaula',
#  'esperance',
#  'ribeira grande',
#  'katsuura',
#  'mantua',
#  'saint-augustin',
#  'itapecerica',
#  'beni',
#  'kitale',
#  'dikson',
#  'ambon',
#  'taolanaro',
#  'chakia',
#  'huejuquilla el alto',
#  'port moresby',
#  'vestmannaeyjar',
#  'longyearbyen',
#  'urdzhar',
#  'saint george',
#  'chokurdakh',
#  'at-bashi',
#  'leningradskiy',
#  'baturaja',
#  'tiksi',
#  'morehead',
#  'santander',
#  'nyimba',
#  'itirucu',
#  'sorong',
#  'ayia marina',
#  'ust-ishim',
#  'hithadhoo',
#  'bereda',
#  'busselton',
#  'souillac',
#  'grand forks',
#  'chittaurgarh',
#  'gerash',
#  'dingle',
#  'cabedelo',
#  'loandjili',
#  'pavilosta',
#  'illapel',
#  'abalak',
#  'swellendam',
#  'ubinskoye',
#  'sorland',
#  'barentsburg',
#  'srandakan',
#  'mangla',
#  'dali',
#  'sao miguel do araguaia',
#  'jamestown',
#  'saint-philippe',
#  'zhigansk',
#  'arraial do cabo',
#  'druzhba',
#  'hihifo',
#  'naliya',
#  'gedo',
#  'nanortalik',
#  'tuktoyaktuk',
#  'aurora',
#  'neryungri',
#  'batagay-alyta',
#  'lavrentiya',
#  'impfondo',
#  'palu',
#  'kedougou',
#  'airai',
#  'mahebourg',
#  'sisimiut',
#  'kautokeino',
#  'ngukurr',
#  'palmer',
#  'kimbe',
#  'hilo',
#  'georgetown',
#  'lakes entrance',
#  'marivan',
#  'atambua',
#  'clyde river',
#  'el faiyum',
#  'lata',
#  'zelenets',
#  'westport',
#  'verkhoyansk',
#  'kabanjahe',
#  'torbay',
#  'bethel',
#  'norman wells',
#  'sulangan',
#  'talawdi',
#  'coihaique',
#  'sao filipe',
#  'kerki',
#  'bandarbeyla',
#  'flinders',
#  'cherskiy',
#  'ust-kamchatsk',
#  'salalah',
#  'denpasar',
#  'rucheng',
#  'surt',
#  'tha bo',
#  'blenheim',
#  'mys shmidta',
#  'bengkulu',
#  'saint-pierre',
#  'niltepec',
#  'monze',
#  'kahului',
#  'vaitupu',
#  'bogorodskoye',
#  'lufkin',
#  'bolungarvik',
#  'tasiilaq',
#  'salihorsk',
#  'vila franca do campo',
#  'cidreira',
#  'san patricio',
#  'palabuhanratu',
#  'los llanos de aridane',
#  'andenes',
#  'beroroha',
#  'zyryanka',
#  'kyshtovka',
#  'sarangani',
#  'kieta',
#  'nelson bay',
#  'limoges',
#  'vigrestad',
#  'khovu-aksy',
#  'marawi',
#  'kudahuvadhoo',
#  'samarai',
#  'oussouye',
#  'bargal',
#  'kaitangata',
#  'la ronge',
#  'vilhena',
#  'nemuro',
#  'iqaluit',
#  'sibolga',
#  'saiha',
#  'nizhneyansk',
#  'lazaro cardenas',
#  'yulara',
#  'takapau',
#  'stulovo',
#  'general elizardo aquino',
#  'darhan',
#  'dujuma',
#  'qiongshan',
#  'lotofaga',
#  'mayo',
#  'durban',
#  'narsaq',
#  'vila velha',
#  'constitucion',
#  'pilar',
#  'aragarcas',
#  'badarwas',
#  'saint-joseph',
#  'krasnoselkup',
#  'ulladulla',
#  'sao joao da barra',
#  'khandyga',
#  'caraballeda',
#  'tessalit',
#  'pincher creek',
#  'taicheng',
#  'portland',
#  'raudeberg',
#  'yellowknife',
#  'kalabo',
#  'hervey bay',
#  'provideniya',
#  'buraydah',
#  'pacific grove',
#  'port keats',
#  'olafsvik',
#  'estevan',
#  'colares',
#  'saint-georges',
#  'nhulunbuy',
#  'mecca',
#  'chontalpa',
#  'yar-sale',
#  'chimore',
#  'pochutla',
#  'curaca',
#  'tabou',
#  'lorengau',
#  'alice springs',
#  'vao',
#  'duz',
#  'avarua',
#  'faanui',
#  'kotka',
#  'santa isabel do rio negro',
#  'kasongo',
#  'sola',
#  'baykit',
#  'one hundred mile house',
#  'paamiut',
#  'garissa',
#  'markova',
#  'amapa',
#  'semenivka',
#  'okhotsk',
#  'carmen',
#  'havoysund',
#  'luba',
#  'potchefstroom',
#  'margate',
#  'ayan',
#  'naifaru',
#  'zhuhai',
#  'medea',
#  'santa cecilia',
#  'chernyshevskiy',
#  'tokur',
#  'naze',
#  'senanga',
#  'parksville',
#  'jalu',
#  'port blair',
#  'caravelas',
#  'amderma',
#  'karaul',
#  'kununurra',
#  'itoman',
#  'gorontalo',
#  'ilulissat',
#  'santa cruz',
#  'christchurch',
#  'bacuit',
#  'udachnyy',
#  'paciran',
#  'tubuala',
#  'fortuna',
#  'belaya gora',
#  'komsomolskiy',
#  'berlevag',
#  'micheweni',
#  'taoudenni',
#  'sisophon',
#  'kibala',
#  'havre-saint-pierre',
#  'machala',
#  'chambas',
#  'rock sound',
#  'bowen',
#  'tecoanapa',
#  'mumbwa',
#  'solovetskiy',
#  'tupik',
#  'caluquembe',
#  'nairobi',
#  'vredendal',
#  'comodoro rivadavia',
#  'havelock',
#  'pangai',
#  'te anau',
#  'sioux lookout',
#  'dolbeau',
#  'moron',
#  'akyab',
#  'roma',
#  'okahandja',
#  'tuburan',
#  'kuala lipis',
#  'yeppoon',
#  'zeya',
#  'teguldet',
#  'hualmay',
#  'bull savanna',
#  'buala',
#  'eureka',
#  'izumo',
#  'alofi',
#  'conel',
#  'nguiu',
#  'corinth',
#  'batalha',
#  'villablino',
#  'itapirapua',
#  'nadvoitsy',
#  'frederikshavn',
#  'saint anthony',
#  'kindu',
#  'kampene',
#  'san isidro',
#  'teahupoo',
#  'bambous virieux',
#  'sitka',
#  'pyapon',
#  'port augusta',
#  'hasaki',
#  'kouango',
#  'pokhara',
#  'ampanihy',
#  'isla vista',
#  'guymon',
#  'yialos',
#  'kathu',
#  'codrington',
#  'carnarvon',
#  'agadir',
#  'belyy yar',
#  'jinchang',
#  'taltal',
#  'fallon',
#  'yelets',
#  'khonuu',
#  'pueblo nuevo',
#  'avera',
#  'auki',
#  'san cristobal',
#  'yaan',
#  'tsiroanomandidy',
#  'delano',
#  'sobolevo',
#  'sexsmith',
#  'baruun-urt',
#  'severobaykalsk',
#  'la cruz',
#  'nata',
#  'sechura',
#  'tuy hoa',
#  'sawang daen din',
#  'severo-kurilsk',
#  'tuatapere',
#  'porto walter',
#  'biltine',
#  'santo nino',
#  'senador jose porfirio',
#  'concarneau',
#  'bam',
#  'ituni',
#  'liling',
#  'goure',
#  'pingliang',
#  'takoradi',
#  'chupei',
#  'bandar-e lengeh',
#  'majenang',
#  'viedma',
#  'acarau',
#  'ballina',
#  'husavik',
#  'makakilo city',
#  'fevralsk',
#  'lincoln',
#  'betioky',
#  'kualakapuas',
#  'lodi',
#  'lompoc',
#  'careiro da varzea',
#  'hanamaki',
#  'srednekolymsk',
#  'porto santo',
#  'morant bay',
#  'touros',
#  'morondava',
#  'charlestown',
#  'ust-kalmanka',
#  'yatou',
#  'tamandare',
#  'kiruna',
#  'boende',
#  'pangnirtung',
#  'harper',
#  'namibe',
#  'hammerfest',
#  'isangel',
#  'owando',
#  'bonthe',
#  'demirci',
#  'hofn',
#  'rawannawi',
#  'golspie',
#  'itarema',
#  'jumla',
#  'wainwright',
#  'tautira',
#  'ust-karsk',
#  'kloulklubed',
#  'guerrero negro',
#  'ostrovnoy',
#  'millinocket',
#  'traverse city',
#  'korla',
#  'wamba',
#  'aklavik',
#  'necochea',
#  'waw',
#  'constantine',
#  'stornoway',
#  'dumas',
#  'bozoum',
#  'coari',
#  'karabuk',
#  'port-de-paix',
#  'cockburn town',
#  'zhaoyuan',
#  'axim',
#  'belvedere marittimo',
#  'tommot',
#  'duki',
#  'talnakh',
#  'haines junction',
#  'sabha',
#  'caxito',
#  'laguna',
#  'wolmaranstad',
#  'bethanien',
#  'phangnga',
#  'adolfo lopez mateos',
#  'chagda',
#  'rio grande',
#  'bilma',
#  'nome',
#  'beringovskiy',
#  'abu kamal',
#  'mushie',
#  'lolua',
#  'jumilla',
#  'bongandanga',
#  'palora',
#  'bara',
#  'halalo',
#  'ambulu',
#  'esna',
#  'petatlan',
#  'sao joao do piaui',
#  'burica',
#  'sinnamary',
#  'asfi',
#  'felidhoo',
#  'salur',
#  'mnogovershinnyy',
#  'tateyama',
#  'poum',
#  'sawtell',
#  'murud',
#  'lupiro',
#  'never',
#  'vanavara',
#  'yantal',
#  'nakambala',
#  'khormuj',
#  'kostino',
#  'hamilton',
#  'bandar-e torkaman',
#  'aketi',
#  'nizhniy kuranakh',
#  'formoso do araguaia',
#  'kudat',
#  'burnie',
#  'romny',
#  'umzimvubu',
#  'kamenka',
#  'davila',
#  'mana',
#  'kyra',
#  'camacha',
#  'ruatoria',
#  'hailar',
#  'osypenko',
#  'luganville',
#  'abapo',
#  'rio gallegos',
#  'cocobeach',
#  'basyanovskiy',
#  'nishihara',
#  'dubbo',
#  'shingu',
#  'quatre cocos',
#  'inirida',
#  'lamu',
#  'klaksvik',
#  'cayenne',
#  'japura',
#  'marystown',
#  'inuvik',
#  'san vicente de canete',
#  'karamay',
#  'kearney',
#  'thunder bay',
#  'pedasi',
#  'panubigan',
#  'tarudant',
#  'ushtobe',
#  'cegledbercel',
#  'junnar',
#  'kuching',
#  'martapura']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
settings = {
    "units": "imperial", 
    "appId": api_key
}


city_name=[]
city_id=[]
city_long=[]
city_lat=[]
city_humidity=[]
city_cloudiness=[]
city_temperature=[]
city_wind_speed=[]



for city in cities:
    try:
        current_weather=owm.get_current(city,**settings)
        city_name.append(current_weather['name'])
        city_id.append(current_weather['id'])
        city_long.append(current_weather['coord']['lon'])
        city_lat.append(current_weather['coord']['lat'])
        city_humidity.append(current_weather['main']['humidity'])
        city_cloudiness.append(current_weather['clouds']['all'])
        city_temperature.append(current_weather['main']['temp'])
        city_wind_speed.append(current_weather['wind']['speed'])

    except (NameError, HTTPError):
        pass

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Keys = ("Name", "ID", "Temperature (C)", "Humidity", "Cludiness", "Wind Speed")
#Values = (city_name, city_id, city_temperature, city_humidity, city_cloudiness, city_wind_speed)

data_dict= {
    "Name": city_name,
    "ID": city_id,
    "Latitude": city_lat,
    "Longitutde": city_long,
    "Temperature (F)": city_temperature,
    "Humidity": city_humidity,
    "Cloudiness": city_cloudiness,
    "Wind Speed": city_wind_speed
}

with open('city_data.csv', 'w') as f:  # Just use 'w' mode in 3.x
    w = csv.DictWriter(f, data_dict.keys())
    w.writeheader()
    w.writerow(data_dict)

weather_data = pd.DataFrame(data_dict).set_index('Name')
weather_data
# Out:
#                                ID  Latitude  Longitutde  Temperature (F)  \
# Name
# Punta Arenas              3874787    -53.16      -70.91            52.38
# Luderitz                  3355672    -26.65       15.16            58.39
# Pisco                     3932145    -13.71      -76.20            71.60
# Hermanus                  3366880    -34.42       19.24            62.91
# Thompson                  6165406     55.74      -97.86            15.80
# Port Alfred                964432    -33.59       26.89            68.54
# Mar del Plata             3863379    -46.43      -67.52            54.16
# Kodiak                    4407665     39.95      -94.76            53.49
# Albany                    5106834     42.65      -73.75            29.82
# Ushuaia                   3833367    -54.81      -68.31            53.60
# Upernavik                 3418910     72.79      -56.15           -10.56
# Lensk                     2020838     60.71      114.91             8.80
# Qaanaaq                   3831208     77.48      -69.36           -26.31
# Rikitea                   4030556    -23.12     -134.97            79.72
# Port Elizabeth            4501427     39.31      -74.98            47.10
# Kanashevo                 1504716     55.21       62.07            28.81
# Broome                    2656067     52.47        1.45            39.94
# Hovd                      7626384     63.83       10.70            35.33
# Cabo San Lucas            3985710     22.89     -109.91            75.13
# Nuuk                      3421319     64.17      -51.74            12.20
# Ponta do Sol              3453439    -20.63      -46.00            69.91
# Mount Gambier             2156643    -37.83      140.78            60.80
# Vostok                    2013279     46.45      135.83            15.91
# Donegal                   2964752     54.65       -8.11            44.62
# Adrar                     2508813     27.87       -0.29            62.60
# East London               1006984    -33.02       27.91            76.12
# Sao Jose da Coroa Grande  3388456     -8.90      -35.15            78.28
# Bluff                     2175403    -23.58      149.07            83.86
# Mataura                   6201424    -46.19      168.86            70.81
# Saldanha                  2737599     41.42       -6.55            44.80
# ...                           ...       ...         ...              ...
# Davila                    1715335     18.47      120.58            75.20
# Mana                       789988     43.52       20.24            37.51
# Camacha                   2270385     33.08      -16.33            60.80
# Hailar                    2037078     49.20      119.70            26.35
# Osypenko                   699329     48.04       34.39            33.80
# Luganville                2136150    -15.51      167.18            74.59
# Abapo                     3924668    -18.83      -63.47            63.88
# Rio Gallegos              3838859    -51.62      -69.22            51.80
# Cocobeach                 2401357      1.01        9.58            82.40
# Nishihara                 1850144     35.74      139.53            47.66
# Dubbo                     2168305    -32.25      148.60            82.40
# Shingu                    1847947     33.72      135.99            46.40
# Quatre Cocos              1106643    -20.21       57.76            79.92
# Inirida                   3671450      3.87      -67.92            76.39
# Lamu                      1623890      0.57      122.30            75.67
# Klaksvik                  2618795     62.23       -6.59            41.00
# Cayenne                   3382160      4.94      -52.33            78.80
# Japura                    1642773     -0.42      102.29            73.06
# Marystown                 6067472     47.17      -55.16            36.00
# Inuvik                    5983607     68.36     -133.71            21.74
# San Vicente de Canete     3928993    -13.08      -76.38            68.20
# Kearney                   5071348     40.70      -99.08            47.98
# Thunder Bay               6166142     48.41      -89.26            47.08
# Pedasi                    3703239      7.53      -80.03            78.19
# Panubigan                 1957309      7.13      122.25            78.80
# Ushtobe                   1517637     45.25       77.98            33.01
# Cegledbercel              3054542     47.22       19.67            41.29
# Junnar                    1268761     19.21       73.88            58.66
# Kuching                   1735634      1.56      110.34            77.00
# Martapura                 1636022     -3.41      114.85            75.20
#
#                           Humidity  Cloudiness  Wind Speed
# Name
# Punta Arenas                    81          75        9.17
# Luderitz                        94          48        9.31
# Pisco                           30          75       19.46
# Hermanus                        94          68        2.93
# Thompson                        43          20       13.87
# Port Alfred                     96           0        1.99
# Mar del Plata                   81           0        4.16
# Kodiak                          83          90        9.17
# Albany                          53           1       17.22
# Ushuaia                         62          40        8.05
# Upernavik                      100          24        8.75
# Lensk                           68          56        5.61
# Qaanaaq                         78          20       10.98
# Rikitea                         97          80       17.69
# Port Elizabeth                  24           1       16.11
# Kanashevo                       63          40        4.47
# Broome                          86          80        3.83
# Hovd                            64          75       47.20
# Cabo San Lucas                  47           5        9.17
# Nuuk                            56          20       19.46
# Ponta do Sol                    87          68        2.82
# Mount Gambier                  100          90        8.05
# Vostok                          49           0        2.93
# Donegal                         91          68       15.23
# Adrar                           23           0        9.17
# East London                     91           0       24.52
# Sao Jose da Coroa Grande        93          44        5.61
# Bluff                           63           0        5.61
# Mataura                         51          92        5.95
# Saldanha                        68           0        4.94
# ...                            ...         ...         ...
# Davila                          78          20        2.24
# Mana                            78           0        2.24
# Camacha                         72          20        8.05
# Hailar                          52          48       11.65
# Osypenko                        74           0       11.18
# Luganville                     100          92        0.36
# Abapo                           97           0        1.92
# Rio Gallegos                    87           0        4.70
# Cocobeach                       83          75        9.17
# Nishihara                       39          20        4.70
# Dubbo                           51          56        8.05
# Shingu                          61          20       13.87
# Quatre Cocos                    83          75       11.41
# Inirida                         94          68        2.15
# Lamu                            94          12        3.15
# Klaksvik                        86          64       12.75
# Cayenne                         83           0        3.36
# Japura                          95          56        2.82
# Marystown                      100          80       14.56
# Inuvik                          62          20       17.22
# San Vicente de Canete           86           8        2.37
# Kearney                         93          90       11.41
# Thunder Bay                     20          40       14.99
# Pedasi                          83           0       17.69
# Panubigan                       78          20        3.36
# Ushtobe                         89          80        3.04
# Cegledbercel                   100           0        2.24
# Junnar                          72           0        2.37
# Kuching                         88          75        3.36
# Martapura                      100          20        6.93
#
# [524 rows x 7 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data['Latitude'],weather_data['Temperature (F)'], edgecolor='black')
plt.grid()
plt.title("City Latitude vs. Max Temperature (03/15/2019)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data['Latitude'],weather_data['Humidity'], edgecolor='black')
plt.grid()
plt.title("City Latitude vs. Humidity (03/15/2019)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data['Latitude'],weather_data['Cloudiness'], edgecolor='black')
plt.grid()
plt.title("City Latitude vs. Cloudiness (03/15/2019)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data['Latitude'],weather_data['Wind Speed'], edgecolor='black')
plt.grid()
plt.title("City Latitude vs. Wind Speed (03/15/2019)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.show()

# %%
x1 = weather_data['Latitude']

y1 = weather_data['Temperature (F)']
y2 = weather_data['Humidity']
y3 = weather_data['Cloudiness']
y4 = weather_data['Wind Speed']

fig = plt.figure(1)

plt.subplot(4, 1, 1)
plt.plot(x1, y1, 'o')
plt.title('Latitude vs Multiple Variables')
plt.ylabel('Temperature (F)')

plt.subplot(4, 1, 2)
plt.plot(x1, y2, 'o')
plt.xlabel('Latitutde')
plt.ylabel('Humidity')

plt.subplot(4, 1, 3)
plt.plot(x1, y3, 'o')
plt.xlabel('Latitutde')
plt.ylabel('Cloudiness')

plt.subplot(4, 1, 4)
plt.plot(x1, y4, 'o')
plt.xlabel('Latitutde')
plt.ylabel('Wind Speed')


#fig.tight_layout()
fig.set_size_inches(w=11,h=15)
fig_name = 'plot.png'
fig.savefig(fig_name)
